# %%
name = int("10")

print(type(name))
# Out:
# <class 'int'>

# %% [markdown]
# ## Casting

# %%
a = 10

b = str(a)

print(type(b))
# Out:
# <class 'str'>

# %%
num = complex(20)

print(num)
# Out:
# (20+0j)

# %%
a = int(20+5j)

print(type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a = int(20+5j)
#       3 print(type(a))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
a = float("10.2")


print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a = float("10.2ncvn")
#       4 print(a)
#
# ValueError: could not convert string to float: '10.2ncvn'

# %%
z = str(10)

print(z)
# Out:
# 10

# %%
a = 0j

b = int(a)

print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 a = 0j
# ----> 3 b = int(a)
#       5 print(b)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
c = "10.5jkjk"

d = float(c)

print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 c = "10.5jkjk"
# ----> 3 d = float(c)
#       5 print(d)
#
# ValueError: could not convert string to float: '10.5jkjk'

# %% [markdown]
# It a good "idea" to write something on copy
#
#
# It a good  to 'write' something on copy

# %%
print( "It a good "idea" to write something on copy")
# Out:
# It a good "idea" to write something on copy

# %% [markdown]
# twinkle twinkle little star
#
# How I "wonder"
#
#         what u are

# %%
a = 'I am a python developer'

if "pythodsdn" not in a:
    print("Python is not in the string")
# Out:
# Python is not in the string

# %%
name = "PrinTOOce"

print(name.upper())
# Out:
# PRINTOOCE

# %%
-4  -1

# %%
name = "PrinTOOce"

print(name.lower())
# Out:
# printooce

# %%
name = "      prince"
print(name.strip())
# Out:
# prince

# %%
name = "Prince"
print(name.replace("P", "H"))
# Out:
# Hrince

# %% [markdown]
# ## Split

# %%
name = "Prince* Aman* cat* dog "
print(name.split("*"))
# Out:
# ['Prince', ' Aman', ' cat', ' dog ']

# %%
fname, lname = "prince", 'singh'

print(fname+ " " + lname)
# Out:
# prince singh

# %%
num=10
name="Prince"

print(num+name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 num=10
#       2 name="Prince"
# ----> 4 print(num+name)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
age = 21
name = "Prince"

print(f"My name is {name}. My age is {age} ")
# Out:
# My name is Prince. My age is 21

# %%
name = "Prince"
age=21
course= "B.Tech"


text=f"My name is {name}, My age is {age} and I am pursuing {course}"

print(text)
# Out:
# My name is Prince, My age is 21 and I am pursuing B.Tech

# %%
number = 21.656735625

text = f"This number is {number:.2f}"

print(text)
# Out:
# This number is 21.66

# %%
num = 10

text= f"multiply: {num+10}"
print(text)
# Out:
# multiply: 20

# %%
sbji = 20

fruits = 100


text = f"total paisa = {sbji+fruits}"

print(text)
# Out:
# total paisa = 120

# %%
carrot = 10

text = f"Carrot price is {"Expensive" if carrot> 30 else "sasta"}"

print(text)
# Out:
# Carrot price is sasta

# %%
name = "Prince"

text = f"Hello, {name.lower()}"

print(text)
# Out:
# Hello, prince

# %%
price = 10000
name = "Prince"
age= 21

text ="My name is {1}, My age is {0} and U can buy me at {1}"

print(text.format(age,  price))
# Out:
# My name is 10000, My age is 21 and U can buy me at 10000

# %%
txt = "My name is : \"Prince \"" 

print(txt)
# Out:
# My name is : "Prince "

# %%
text = "hello\nworld"
print(text)
# Out:
# hello
# world

# %% [markdown]
# this is backslash \

# %%
text= "this is backslash \\"

print(text)
# Out:
# this is backslash \

# %%
It's me

# %%
print('It\'s me')
# Out:
# It's me

# %%
name = 'deepak'

x = name.find("e")

print(x)
# Out:
# 1

# %%
print("abc" > "bca")
# Out:
# False

# %%
print(bool(x))
# Out:
# True

# %%
name = ['a']

print(bool(name))
# Out:
# True

# %%
a = 10.0

print(isinstance(a, float))
# Out:
# True

# %% [markdown]
# ## Operator
# Assignment operators
# Comparison operators
# Logical operators
# Identity operators
# Membership operators
# Bitwise operators

# %%
print(11%2)
# Out:
# 1

# %%
print(num:=10)
# Out:
# 10

# %%
print("a" is "A")
# Out:
# False
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Windows\Temp\ipykernel_36044\806217643.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   print("a" is "A")

# %%
name = "Prince#aman#dog,ca"

print(name.split("#"))
# Out:
# ['Prince', 'aman', 'dog,ca']

# %%
name = "                  prince"

print(name.replace("p", 'h'))
# Out:
#                   hrince

# %% [markdown]
# My name is Prince, My age is : 21

# %%
name = "Prince"
age = 38

text = "My name is {1}, My age is {0} "
print(text.format(age, name))
# Out:
# My name is Prince, My age is 38

# %% [markdown]
# My name is "Prince"

# %%
print("\t My name is \"Prince\" ")
# Out:
# 	 My name is "Prince"

# %%
print("a" > "A")
# Out:
# True

# %%
print(bool(" "))
# Out:
# True

# %%
print(isinstance(10, str))
# Out:
# False

# %%
name = ["Prince","Cat", "Amjhfbbhsan", "Om", "Prince"]

print(name)
# Out:
# ['Prince', 'Aman', 'Om', 'Prince']
