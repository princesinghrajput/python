# %%
my_set = { "Prince", "Mango", "set", "abc", 29, False, 0 }


print(len(my_set))

# %%
my_list = [ "Prince", "Mango", "set", "abc", 29,True, "Prince" ]
my_list[0]="cat"

print(my_list)

# %%
new_set = set(("Prince", "Mango", "set", "abc", 29, False, 0))

for x in new_set:
    print(x)

# %%
my_set= {"a", "A", "b", "C", 29, 80, False}

print(my_set)

# %%
my_list = ["a", "A", "b", "C", 29, 80, False]

# %%
x = set(my_list)

print(x)

# %%
dummy_set = {"a", "A", "b"}

dummy_set.add("Prince")

print(dummy_set)

# %%
thisset = {"apple", "banana", "cherry"}
newset="prince",

thisset.update(newset)

print(thisset)

# %%
set1={"hello", "hey"}

set1.clear()
set1.add("mango","cherry")

print(set1)

# %%
list1=["hello", "hey"]
list1.pop()

print(list1)

# %%
thisset1={"hello", "hey"}

newset1={29,True}

x = thisset1 | newset1

print(x)

# %%
set1 = {"a", "b", "c", 4, True}
set2 = {1, 2, 3}
set3 = {"John", "Elena", "apple"}
set4 = {"apple", "bananas", "cherry", 1}


y = set1 | set2 | set3 | set4

print(len(y))

# %%
set_new = {0,0,0,0,0}

print(len(set_new))

# %%
new_list= [2]*5

print(new_list)

# %% [markdown]
# ## Dictionay

# %%
employee = {
    "name":["Prince", "mango"],

    "company":"sensation",
    "company":"HCL",

    "favfood":"sensation"

}

if "age" in employee:
    print("Haa age bta rkha hai!")

else:
    print("Nahi bta rkha hai!")

# %%
thisdict = dict(name = "John", age = 36, country = "Norway")

thisdict.get("country")

# %%
employee = {
    "name":["Prince", "mango"],
    "company":"sensation",
    "company":"HCL",
    "favfood":"sensation"

}

employee["favfood"]="vadapaav"

print(employee)

# %%
employee = {
    "name":["Prince", "mango"],
    "company":"sensation",
    "company":"HCL",
    "favfood":"sensation"

}

employee.update({"favfood":"samosa"})

print(employee)

# %%
employee = {
    "name":["Prince", "mango"],
    "company":"sensation",
    "company":"HCL",
    "favfood":"Pizza"

}

# x = employee.get("favfood")
# employee.keys()

# employee.values()


employee.items()
# Out:
# dict_items([('name', ['Prince', 'mango']), ('company', 'HCL'), ('favfood', 'Pizza')])

# %%
employee = {
    "name":"Prince",
    "company":"sensation",
    "company":"HCL",
    "favfood":"sensation"

}


x = employee.items()
print(x)
# Out:
# dict_items([('name', 'Prince'), ('company', 'HCL'), ('favfood', 'sensation')])
