# %% [markdown]
# ## Tuple

# %%
new_tuple = ("Prince", "Mohan", "Rohan", 29, 40)

print(type(new_tuple))
# Out:
# <class 'tuple'>

# %%
name = "Prince", "Aman"

print(name)
# Out:
# ('Prince', 'Aman')

# %%
single_tuple = (29,)

print(type(single_tuple))
# Out:
# <class 'int'>

# %%
list1=["Prince", "Mango"]

list_to_tuple = tuple(list1)

print(type(list_to_tuple))
# Out:
# <class 'tuple'>

# %%
new_tuple = ("Prince", "Mohan", "Rohan", 29, 40)

del new_tuple

print(new_tuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 new_tuple = ("Prince", "Mohan", "Rohan", 29, 40)
#       3 del new_tuple
# ----> 5 print(new_tuple)
#
# NameError: name 'new_tuple' is not defined

# %%
new_tuple = ("Prince", "Mohan", "Rohan", 29, 40)

for i in new_tuple:
    print(i)
# Out:
# Prince
# Mohan
# Rohan
# 29
# 40

# %% [markdown]
# ("Prince", "mango")

# %%
tuple1 = ("Prince", "mango")*10

print(tuple1)
# Out:
# ('Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango', 'Prince', 'mango')

# %%
list1=["Prince", "Mango"]

list_to_tuple = tuple(list1)


tuple_to_list= list(list_to_tuple)

print(type(tuple_to_list))
# Out:
# <class 'list'>

# %%
a = (2,5)+("Prince", "animal")

print(a)
# Out:
# (2, 5, 'Prince', 'animal')

# %%
new_tuple = ("Prince", "Mohan", "Rohan", 29, 40)

a,b,c,d,e = new_tuple

print(d)
# Out:
# 29

# %%
newsted_tuple = (('a','b', 'c'), (1,2,3), ["prince","hello"])

x=newsted_tuple[2][1]=29

print(x)
# Out:
# 29

# %%
import timeit
print(timeit.timeit(stmt="('a','b','c')", number=100000))
print(timeit.timeit(stmt="['a','b','c']",number=100000))
# Out:
# 0.0007767000006424496
# 0.004313200000979123
