# %%
class Computer:
    def config(self):
        print("i7","512gb", "16gb")


com1=Computer()

com1.config()
# Out:
# i7 512gb 16gb

# %%
class Computer:

    def __init__(self, cpu, ram):
        self.cpu= cpu
        self.ram=ram

    def config(self):
        print("Config is: ", self.cpu, self.ram)


com1=Computer("i5", 16)

com1.config()
# Out:
# Config is:  i5 16
