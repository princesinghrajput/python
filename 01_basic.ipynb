# %%
print("Hello Prince")
# Out:
# Hello Prince

# %% [markdown]
# # How to print hello world

# %%
print("Prince")
# Out:
# Prince

# %% [markdown]
# ## How to comment
#     Single Line comment

# %%
# print("Hello world!")
print("Hello")
# print("Dog")
print("Prince")
# Out:
# Hello
# Prince

# %%
''' 
this is a multi-line comments

'''
# Out:
# ' \nprint("Prince")\nprint("Prince")\nprint("Prince")\n\n'

# %% [markdown]
# ## Literal constants
#     integer
#     float
#     complex
#     string

# %%
a = 10  #integer
print(a)

print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 20.5 #float
print(b)

type(b)
# Out:
# 20.5
# float

# %%
n = 10+5j
print(n)
type(n)
# Out:
# (10+5j)
# complex

# %%
name = "P"

print(name)
type(name)
# Out:
# P
# str

# %%
name = '10'
firstname = "john"
type(name)
# Out:
# str

# %%
name = "Prince"
print(type(name))
# Out:
# <class 'str'>

# %%
poem = """  

twinkle twinkle



"""

print(poem)
# Out:
#
#
# twinkle twinkle

# %% [markdown]
# ## Variables

# %%
# name = "Prince"
# print(name)


# _name = "Prince"

# print(_name)

123name= "Prince"

print(123name)
# Out:
#   Cell In[4], line 9
#     123name= "Prince"
#       ^
# SyntaxError: invalid decimal literal

# %%
#valid variables
name123 = "Prince"


#invalid variables
123name= "jsdjslj"

# %%
Name="Prince"

print(name)
# Out:
# Prince

# %%
_1prince="Hello"

1_234="prince"


name123="ljdljs"

# %%
age=29
Age=30

print(age)
# Out:
# 29

# %%
type = "Prince"

print(type)
# Out:
# Prince

# %%
lambda = "lkfklslk"

print(lambda)
# Out:
#   Cell In[8], line 1
#     lambda = "lkfklslk"
#            ^
# SyntaxError: invalid syntax

# %%
def = 20

print(def)
# Out:
#   Cell In[9], line 1
#     def = 20
#         ^
# SyntaxError: invalid syntax

# %%
prince@= "lkmklmsk"
print(prince@)
# Out:
#   Cell In[10], line 2
#     print(prince@)
#                  ^
# SyntaxError: invalid syntax

# %%
my*name = "Prince"

print(my-name)

# %%
#camelcase
restaurantName = "Restaurant"
print(restaurantName)
# Out:
# Restaurant

# %%
#Pascal case

RestaurantName = "jknsjk"

print(RestaurantName)
# Out:
# jknsjk

# %%
#snake case
restaurant_name = "kjdlksjk"

print(restaurant_name)
# Out:
# kjdlksjk

# %% [markdown]
# ## Assigning multiple values in multiple variables

# %%
x, y, z = 10, 20

print(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 x, y, z = 10, 20
#       3 print(y)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
first_name , last_name = "Prince", "singh"
print(first_name)
# Out:
# Prince

# %%
name = ['prince ', 'shivam ', 10, 20]

x,y,z,a = name


print(x+y,z+a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       1 name = ['prince ', 'shivam ', 10, 20]
#       3 x,y,z,a = name
# ----> 5 print(type(a))
#       7 print(x+y,z+a)
#
# TypeError: 'str' object is not callable

# %%
name = "hello"

type(name)
# Out:
# str
